# %% [markdown]
# ## Chapter 4 Linear Regression

# %%
# Import our main libraries
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
url = "http://peopleanalytics-regression-book.org/data/ugtests.csv"
ugtests = pd.read_csv(url)

# %%
ugtests
# Out:
#      Yr1  Yr2  Yr3  Final
# 0     27   50   52     93
# 1     70  104  126    207
# 2     27   36  148    175
# 3     26   75  115    125
# 4     46   77   75    114
# ..   ...  ...  ...    ...
# 970   78   68  166    176
# 971   44   61  116    155
# 972   80   97  121    148
# 973   37   79  120    178
# 974   58  135  125    172
#
# [975 rows x 4 columns]

# %%
ugtests.describe()
# Out:
#               Yr1         Yr2         Yr3       Final
# count  975.000000  975.000000  975.000000  975.000000
# mean    52.145641   92.398974  105.121026  148.962051
# std     14.924083   30.038473   33.507052   44.339663
# min      3.000000    6.000000    8.000000    8.000000
# 25%     42.000000   73.000000   81.000000  118.000000
# 50%     53.000000   94.000000  105.000000  147.000000
# 75%     62.000000  112.000000  130.000000  175.000000
# max     99.000000  188.000000  198.000000  295.000000

# %%
sns.pairplot(ugtests)

# %%
pearsoncorr = ugtests.corr(method='pearson')
pearsoncorr
# Out:
#             Yr1       Yr2       Yr3     Final
# Yr1    1.000000  0.027509 -0.020090  0.020484
# Yr2    0.027509  1.000000  0.043435  0.321298
# Yr3   -0.020090  0.043435  1.000000  0.666364
# Final  0.020484  0.321298  0.666364  1.000000

# %%
sns.heatmap(pearsoncorr, xticklabels=pearsoncorr.columns,
           yticklabels=pearsoncorr.columns,
           cmap='RdBu_r',
           annot=True,
           linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
# Simple Regression
model1 = smf.ols(formula = "Final ~ Yr3 ", data = ugtests)
ugtests_model1 = model1.fit()
print(ugtests_model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Final   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.443
# Method:                 Least Squares   F-statistic:                     777.1
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):          3.52e-126
# Time:                        20:59:31   Log-Likelihood:                -4793.9
# No. Observations:                 975   AIC:                             9592.
# Df Residuals:                     973   BIC:                             9601.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     56.2669      3.490     16.123      0.000      49.418      63.115
# ...

# %%
# Multiple Regression 
model = smf.ols(formula = "Final ~ Yr3 + Yr2 + Yr1", data = ugtests)
ugtests_model = model.fit()
print(ugtests_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Final   R-squared:                       0.530
# Model:                            OLS   Adj. R-squared:                  0.529
# Method:                 Least Squares   F-statistic:                     365.5
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):          8.22e-159
# Time:                        21:00:56   Log-Likelihood:                -4711.6
# No. Observations:                 975   AIC:                             9431.
# Df Residuals:                     971   BIC:                             9451.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     14.1460      5.480      2.581      0.010       3.392      24.900
# ...

# %%
x = ugtests['Final']
y = ugtests['Yr3']

ax = sns.regplot(x, y)
# Out:
# C:\Users\Teamwork\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
